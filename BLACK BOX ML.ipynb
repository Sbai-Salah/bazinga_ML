# %% [markdown]
# ### What is not ML : The rule based approaches.
#
# Concidering the medical diagnosis.
#
# - Consult textbpoks and medical doctors ( experts)
# - Understanding their diagnosis process.
# - Impletement this as an algorithm : Rule based system.
#
# This doesn't sound too bad ...
# And it was vert popular in 1980s.
#
# it's very labor intensive to build, and don't naturally handle uncertainty.
#
# ### Modern AI
#
# Modern AI says: Don't reverse engineer an expert's decision process. Machines learns on its own. We provide `training data`.
#
# And learning from training data of this form is called `supervised learing`.
#
# ![image.png](attachment:image.png)
#
# -> One-hot encoding : a set of binary features that always has exactly one nonzero value.
